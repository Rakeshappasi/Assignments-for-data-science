# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakeshappasi/Assignments-for-data-science/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
days = [1,2,3,4,5,6,7]
sales_one = [160, 150, 140, 145, 175, 165, 180]
sales_two = [70, 90, 160, 150, 140, 145, 175]
plt.figure(figsize=(1,2), dpi=100)
plt.plot(days, sales_one)
plt.plot(days, sales_two)
plt.title('Assignment 2')
plt.xlabel('days of the week')
plt.ylabel('sales')
plt.grid()
plt.show()

# %%
x = np.arange(0,10)
y = x * x
plt.title("Assignment 1")
plt.plot(x, y, color='R')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py:125: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
x = [1,2,3,4]
y1 = [4,3,2,1]
y2 = [10,20,30,40]
y3 = [40,30,20,10]
y4 = [1,2,1,2]
y5 = [40,70,90,70]
plt.plot(x,y1,'go--')
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')





plt.subplot(3,2,1)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y2,'go--')



plt.subplot(3,2,2)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y2,'go--')

plt.subplot(3,2,3)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y3,'go--')

plt.subplot(3,2,4)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y4,'go--')

plt.subplot(3,2,5)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y5,'go--')

plt.subplot(3,2,6)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y5,'go--')
